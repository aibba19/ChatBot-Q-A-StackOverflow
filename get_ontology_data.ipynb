# %% [markdown]
# <h1>Get Ontology Data</h1>
# CodeOntology is an ontology to model object-oriented programming languages and source code. More info http://codeontology.org/

# %%
from rdfpandas.graph import to_dataframe
import pandas as pd
import rdflib
import preprocessing
import numpy as np
import tfidf
import scipy

# %% [markdown]
# <h2>Load the rdf file in to a dataframe</h2>
#
# Using rdfpandas.graph lybrary we parse the ontology files where are the function names and description in to a dataframe.

# %%
g = rdflib.Graph()
g.parse('DB/Code_Ontology/comments.nt', format = 'nt')
df = to_dataframe(g)
df
# Out:
#                                                               rdfs:comment{Literal}  \
# http://rdf.webofcode.org/woc/                                                   NaN
# http://rdf.webofcode.org/woc/Abstract                                           NaN
# http://rdf.webofcode.org/woc/AccessModifier                                     NaN
# http://rdf.webofcode.org/woc/ActualArgument         The actual argument of a method
# http://rdf.webofcode.org/woc/AnnotationType                                     NaN
# ...                                                                             ...
# http://rdf.webofcode.org/woc/org.jcp.xml.dsig.i...  Defines the XMLDSigRI provider.
# http://rdf.webofcode.org/woc/overrides                                          NaN
# http://rdf.webofcode.org/woc/references                                         NaN
# http://rdf.webofcode.org/woc/returns                                            NaN
# http://rdf.webofcode.org/woc/throws                                             NaN
#
#                                                    rdfs:comment{Literal}(xsd:string)  \
# http://rdf.webofcode.org/woc/                                                    NaN
# http://rdf.webofcode.org/woc/Abstract                                            NaN
# http://rdf.webofcode.org/woc/AccessModifier                                      NaN
# http://rdf.webofcode.org/woc/ActualArgument                                      NaN
# http://rdf.webofcode.org/woc/AnnotationType                                      NaN
# ...                                                                              ...
# http://rdf.webofcode.org/woc/org.jcp.xml.dsig.i...                               NaN
# http://rdf.webofcode.org/woc/overrides                                           NaN
# http://rdf.webofcode.org/woc/references                                          NaN
# http://rdf.webofcode.org/woc/returns                                             NaN
# http://rdf.webofcode.org/woc/throws                                              NaN
#
#                                                                              rdfs:comment{Literal}@en
# http://rdf.webofcode.org/woc/                       An ontology that represents object-oriented pr...
# http://rdf.webofcode.org/woc/Abstract                                           The abstract modifier
# http://rdf.webofcode.org/woc/AccessModifier                                        An access modifier
# http://rdf.webofcode.org/woc/ActualArgument                                                       NaN
# http://rdf.webofcode.org/woc/AnnotationType                                             An annotation
# ...                                                                                               ...
# http://rdf.webofcode.org/woc/org.jcp.xml.dsig.i...                                                NaN
# http://rdf.webofcode.org/woc/overrides              The overrides property relates a method to the...
# http://rdf.webofcode.org/woc/references             The references property relates a method or a ...
# http://rdf.webofcode.org/woc/returns                The returns property relates a method to the v...
# http://rdf.webofcode.org/woc/throws                 The throws property relates a method or a cons...
#
# [87262 rows x 3 columns]

# %% [markdown]
# <h2>Manipolate data</h2>
#
# As we can see from the dataframe we need to manipulate the data since we want to have only the function name, its description and its return values for our purpouse

# %%
#Use the index as a column that is the name of the function 
df.reset_index(level=0, inplace=True)

# %%
#Getting a sample of db for testing
data = df.sample(frac = 0.2)
data
# Out:
#                                                    index  \
# 27580  http://rdf.webofcode.org/woc/java.security.cer...
# 69738  http://rdf.webofcode.org/woc/javax.swing.filec...
# 54477  http://rdf.webofcode.org/woc/javax.naming.ldap...
# 73592  http://rdf.webofcode.org/woc/javax.swing.plaf....
# 66094  http://rdf.webofcode.org/woc/javax.swing.JTabl...
# ...                                                  ...
# 7294   http://rdf.webofcode.org/woc/java.awt.event.In...
# 11494  http://rdf.webofcode.org/woc/java.awt.image.Lo...
# 84986  http://rdf.webofcode.org/woc/jdk.internal.org....
# 54096  http://rdf.webofcode.org/woc/javax.naming.dire...
# 18647  http://rdf.webofcode.org/woc/java.lang.Securit...
#
#                                    rdfs:comment{Literal}  \
# 27580  Creates an {@code X509CertSelector}. Initially...
# 69738  Returns true if the file (directory) can be vi...
# 54477  The control's ASN.1 BER encoded value.\n\n @se...
# 73592                      Width of the area to paint to
# 66094  Invoked when the underlying model has complete...
# ...                                                  ...
# 7294                             the source of the event
# 11494  the specified <code>RenderingHints</code>, or ...
# 84986  Performs a simple DFS of the instructions, ass...
# 54096  Retrieves the number of values in this attribu...
# 18647               a system-dependent security context.
#
#                        rdfs:comment{Literal}(xsd:string)  \
# 27580                                                NaN
# 69738  <code>true</code> if the file/directory can be...
# 54477                                                NaN
# 73592                                                NaN
# 66094                                                NaN
# ...                                                  ...
# 7294                                                 NaN
# 11494                                                NaN
# 84986                                                NaN
# 54096  The nonnegative number of values in this attri...
# 18647                                                NaN
#
#       rdfs:comment{Literal}@en
# 27580                      NaN
# 69738                      NaN
# 54477                      NaN
# 73592                      NaN
# 66094                      NaN
# ...                        ...
# 7294                       NaN
# 11494                      NaN
# 84986                      NaN
# 54096                      NaN
# 18647                      NaN
#
# [17452 rows x 4 columns]

# %%
#Renaming columns names 
df.rename({'index': 'function', 'rdfs:comment{Literal}' : 'description', 'rdfs:comment{Literal}(xsd:string)' : 'return_value', 'rdfs:comment{Literal}@en' : 'description3' }, axis=1, inplace=True)

#Leave only the row where the function is really a function so the line is ending with ')'
df = df.loc[(df['function'].str.endswith(')'))]

df.function
# Out:
# 85       http://rdf.webofcode.org/woc/com.oracle.net.Sd...
# 86       http://rdf.webofcode.org/woc/com.oracle.net.Sd...
# 87       http://rdf.webofcode.org/woc/com.oracle.net.Sd...
# 88       http://rdf.webofcode.org/woc/com.oracle.net.Sd...
# 89       http://rdf.webofcode.org/woc/com.oracle.net.Sd...
#                                ...
# 87244    http://rdf.webofcode.org/woc/org.jcp.xml.dsig....
# 87247    http://rdf.webofcode.org/woc/org.jcp.xml.dsig....
# 87253    http://rdf.webofcode.org/woc/org.jcp.xml.dsig....
# 87254    http://rdf.webofcode.org/woc/org.jcp.xml.dsig....
# 87255    http://rdf.webofcode.org/woc/org.jcp.xml.dsig....
# Name: function, Length: 38636, dtype: object

# %%
#Delete the rows where the function name contains parameter since that rows aren't defintion of functions 
df = df[~df.function.str.contains("parameter")]
df
# Out:
#                                                 function  \
# 85     http://rdf.webofcode.org/woc/com.oracle.net.Sd...
# 86     http://rdf.webofcode.org/woc/com.oracle.net.Sd...
# 87     http://rdf.webofcode.org/woc/com.oracle.net.Sd...
# 88     http://rdf.webofcode.org/woc/com.oracle.net.Sd...
# 89     http://rdf.webofcode.org/woc/com.oracle.net.Sd...
# ...                                                  ...
# 87244  http://rdf.webofcode.org/woc/org.jcp.xml.dsig....
# 87247  http://rdf.webofcode.org/woc/org.jcp.xml.dsig....
# 87253  http://rdf.webofcode.org/woc/org.jcp.xml.dsig....
# 87254  http://rdf.webofcode.org/woc/org.jcp.xml.dsig....
# 87255  http://rdf.webofcode.org/woc/org.jcp.xml.dsig....
#
#                                              description  \
# 85                      Creates a SDP enabled SocketImpl
# 86     Creates an unbound SDP server socket. The {@co...
# 87     Opens a socket channel to a SDP socket.\n\n <p...
# 88     Creates an unconnected and unbound SDP socket....
# 89     Opens a socket channel to a SDP socket.\n\n <p...
# ...                                                  ...
# 87244  Creates a <code>DOMXMLSignature</code> from XM...
# 87247          Initializes a new instance of this class.
# 87253  Returns the ID from a same-document URI (ex: "...
# 87254  Returns true if uri is a same-document URI, fa...
# 87255  Converts an Iterator to a Set of Nodes, accord...
#
#                     return_value description3
# 85                           NaN          NaN
# 86            a new ServerSocket          NaN
# 87     a new ServerSocketChannel          NaN
# 88                  a new Socket          NaN
# 89           a new SocketChannel          NaN
# ...                          ...          ...
# 87244                        NaN          NaN
# 87247                        NaN          NaN
# 87253                        NaN          NaN
# 87254                        NaN          NaN
# 87255           the Set of Nodes          NaN
#
# [38625 rows x 4 columns]

# %%
preprocessing.clean_ontology(df)
df
# Out:
#                                                 function  \
# 85                 com.oracle.net.Sdp-createSocketImpl()
# 86                 com.oracle.net.Sdp-openServerSocket()
# 87          com.oracle.net.Sdp-openServerSocketChannel()
# 88                       com.oracle.net.Sdp-openSocket()
# 89                com.oracle.net.Sdp-openSocketChannel()
# ...                                                  ...
# 87244  org.jcp.xml.dsig.internal.dom.DOMXMLSignature-...
# 87247  org.jcp.xml.dsig.internal.dom.DOMXMLSignatureF...
# 87253  org.jcp.xml.dsig.internal.dom.Utils-parseIdFro...
# 87254  org.jcp.xml.dsig.internal.dom.Utils-sameDocume...
# 87255  org.jcp.xml.dsig.internal.dom.Utils-toNodeSet(...
#
#                                              description  \
# 85                    Creates a SDP enabled Socket tImpl
# 86
# 87
# 88
# 89
# ...                                                  ...
# 87244             Creates a DOMXMLSignature from XML.
# 87247          Initializes a new instance of this class.
# 87253  Returns the ID from a same-document URI (ex: "...
# 87254  Returns true if uri is a same-document URI, fa...
# 87255  Converts an Iterator to a Set of Nodes, accord...
#
#                     return_value description3
# 85                           NaN          NaN
# 86            a new ServerSocket          NaN
# 87     a new ServerSocketChannel          NaN
# 88                  a new Socket          NaN
# 89           a new SocketChannel          NaN
# ...                          ...          ...
# 87244                        NaN          NaN
# 87247                        NaN          NaN
# 87253                        NaN          NaN
# 87254                        NaN          NaN
# 87255           the Set of Nodes          NaN
#
# [38625 rows x 4 columns]

# %%
#count rows where due to preprocessing the description became an empty string
df[df['description'] == ''].index
# Out:
# Int64Index([   86,    87,    88,    89,   211,   214,   473,   519,   674,
#               726,
#             ...
#             87043, 87055, 87060, 87089, 87125, 87166, 87168, 87174, 87190,
#             87199],
#            dtype='int64', length=10260)

# %%
#delete rows where due to preprocessing the description became an empty string
df = df[df['description'] != '']
df
# Out:
#                                                 function  \
# 85                 com.oracle.net.Sdp-createSocketImpl()
# 189    java.applet.Applet$AccessibleApplet-getAccessi...
# 190    java.applet.Applet$AccessibleApplet-getAccessi...
# 191                          java.applet.Applet-Applet()
# 192                         java.applet.Applet-destroy()
# ...                                                  ...
# 87244  org.jcp.xml.dsig.internal.dom.DOMXMLSignature-...
# 87247  org.jcp.xml.dsig.internal.dom.DOMXMLSignatureF...
# 87253  org.jcp.xml.dsig.internal.dom.Utils-parseIdFro...
# 87254  org.jcp.xml.dsig.internal.dom.Utils-sameDocume...
# 87255  org.jcp.xml.dsig.internal.dom.Utils-toNodeSet(...
#
#                                              description  \
# 85                    Creates a SDP enabled Socket tImpl
# 189                      Get the role of this object.
# 190                     Get the state of this object.
# 191    Constructs a new Applet.    Note: Many methods...
# 192    Called by the browser or applet viewer to info...
# ...                                                  ...
# 87244             Creates a DOMXMLSignature from XML.
# 87247          Initializes a new instance of this class.
# 87253  Returns the ID from a same-document URI (ex: "...
# 87254  Returns true if uri is a same-document URI, fa...
# 87255  Converts an Iterator to a Set of Nodes, accord...
#
#                                             return_value description3
# 85                                                   NaN          NaN
# 189    an instance of AccessibleRole describing the r...          NaN
# 190    an instance of AccessibleStateSet containing t...          NaN
# 191                                                  NaN          NaN
# 192                                                  NaN          NaN
# ...                                                  ...          ...
# 87244                                                NaN          NaN
# 87247                                                NaN          NaN
# 87253                                                NaN          NaN
# 87254                                                NaN          NaN
# 87255                                   the Set of Nodes          NaN
#
# [28365 rows x 4 columns]

# %%
df = df[~df['description'].isna()]
df = df[~df['function'].isna()] 
descriptions = df['description']
descriptions
# Out:
# 85                      Creates a SDP enabled Socket tImpl
# 189                        Get the role of this object.
# 190                       Get the state of this object.
# 191      Constructs a new Applet.    Note: Many methods...
# 192      Called by the browser or applet viewer to info...
#                                ...
# 87244               Creates a DOMXMLSignature from XML.
# 87247            Initializes a new instance of this class.
# 87253    Returns the ID from a same-document URI (ex: "...
# 87254    Returns true if uri is a same-document URI, fa...
# 87255    Converts an Iterator to a Set of Nodes, accord...
# Name: description, Length: 28365, dtype: object

# %%
#Clearing text 
descriptions_processed = descriptions.apply(lambda x: preprocessing.clear_text(x))
descriptions_processed
# Out:
# 85                       creates sdp enabled socket timpl
# 189                                       get role object
# 190                                      get state object
# 191      constructs new applet note many methods java a...
# 192      called browser applet viewer inform applet rec...
#                                ...
# 87244                         creates domxmlsignature xml
# 87247                      initializes new instance class
# 87253                       returns id document uri ex id
# 87254       returns true uri document uri false otherwise
# 87255    converts iterator set nodes according xpath da...
# Name: description, Length: 28365, dtype: object

# %%
df['description_processed'] = descriptions_processed
df = df.drop('description3',axis=1)

# %%
df.isna().sum()

df = df.dropna()
df.head()
# Out:
#                                               function  \
# 189  java.applet.Applet$AccessibleApplet-getAccessi...
# 190  java.applet.Applet$AccessibleApplet-getAccessi...
# 193          java.applet.Applet-getAccessibleContext()
# 194              java.applet.Applet-getAppletContext()
# 195                 java.applet.Applet-getAppletInfo()
#
#                                            description  \
# 189                    Get the role of this object.
# 190                   Get the state of this object.
# 193  Gets the Accessible eContext associated with t...
# 194  Determines this applet's context, which allows...
# 195  Returns information about this applet. An appl...
#
#                                           return_value  \
# 189  an instance of AccessibleRole describing the r...
# 190  an instance of AccessibleStateSet containing t...
# 193  an AccessibleApplet that serves as the Accessi...
# 194                              the applet's context.
# 195  a string containing information about the auth...
#
#                                  description_processed
# 189                                   get role object
# 190                                  get state object
# 193  gets accessible econtext associated applet app...
# 194  determines applet context allows applet query ...
# 195  returns information applet applet override met...

# %%
df.to_csv('DB/Preprocessed_ontology.csv', index=False)
