# %%
from rdfpandas.graph import to_dataframe
import pandas as pd
import rdflib
import preprocessing
import numpy as np

# %%
#Load the rdf file in to a dataframe
g = rdflib.Graph()
g.parse('DB/Code_Ontology/comments.nt', format = 'nt')
df = to_dataframe(g)

# %%
pd.set_option('max_colwidth', 5000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.min_rows', 20)
df = df.sample(frac = 0.1)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 rdfs:comment{Literal}  \
# http://rdf.webofcode.org/woc/java.awt.RenderingHints-VALUE_FRACTIONALMETRICS_OFF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Font fractional metrics hint value -- character glyphs are\n positioned with advance widths rounded to pixel boundaries.\n @see #KEY_FRACTIONALMETRICS
# http://rdf.webofcode.org/woc/java.util.concurrent.ForkJoinPool-hasQueuedSubmissions()                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Returns {@code true} if there are any tasks submitted to this\n pool that have not yet begun executing.\n\n @return {@code true} if there are any queued submissions
# http://rdf.webofcode.org/woc/javax.swing.event.UndoableEditEvent-getEdit()                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Returns the edit value.\n\n @return the UndoableEdit object encapsulating the edit
# http://rdf.webofcode.org/woc/java.text.CollationElementIterator-getMaxExpansion(int)                                                                                                                                                                                                                                                                                                                                                                              Return the maximum length of any expansion sequences that end\n with the specified comparison order.\n @param order a collation order returned by previous or next.\n @return the maximum length of any expansion sequences ending\n         with the specified order.\n @since 1.2
# http://rdf.webofcode.org/woc/javax.swing.RowSorter-modelStructureChanged()                                                                                                                                                                                                                                                                                                                                                                                Invoked when the underlying model structure has completely\n changed.  For example, if the number of columns in a\n <code>TableModel</code> changed, this method would be invoked.\n <p>\n You normally do not call this method.  This method is public\n to allow view classes to call it.
# http://rdf.webofcode.org/woc/java.util.Calendar-isSet(int)                                                                                                                                                                                                                                                                                                                                                  Determines if the given calendar field has a value set,\n including cases that the value has been set by internal fields\n calculations triggered by a <code>get</code> method call.\n\n @param field the calendar field to test\n @return <code>true</code> if the given calendar field has a value set;\n <code>false</code> otherwise.
# http://rdf.webofcode.org/woc/java.nio.file.spi.FileSystemProvider-delete(java.nio.file.Path)-parameter-0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               the path to the file to delete
# http://rdf.webofcode.org/woc/javax.swing.JInternalFrame-rootPaneCheckingEnabled                                                                                                                                                                                                                                                                                                                               If true then calls to <code>add</code> and <code>setLayout</code>\n will be forwarded to the <code>contentPane</code>. This is initially\n false, but is set to true when the <code>JInternalFrame</code> is\n constructed.\n\n @see #isRootPaneCheckingEnabled\n @see #setRootPaneCheckingEnabled\n @see javax.swing.RootPaneContainer
# http://rdf.webofcode.org/woc/javax.swing.border.TitledBorder-TOP                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Position the title in the middle of the border's top line.
# http://rdf.webofcode.org/woc/javax.swing.plaf.metal.MetalIconFactory$TreeFolderIcon                                                                                                                                                                                                                       <p>\n <strong>Warning:</strong>\n Serialized objects of this class will not be compatible with\n future Swing releases. The current serialization support is\n appropriate for short term storage or RMI between applications running\n the same version of Swing.  As of 1.4, support for long term storage\n of all JavaBeans&trade;\n has been added to the <code>java.beans</code> package.\n Please see {@link java.beans.XMLEncoder}.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# http://rdf.webofcode.org/woc/java.util.regex.Pattern-compile()                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Copies regular expression to an int array and invokes the parsing\n of the expression which will create the object tree.
# http://rdf.webofcode.org/woc/java.lang.ThreadLocal$ThreadLocalMap-expungeStaleEntries()                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Expunge all stale entries in the table.
# http://rdf.webofcode.org/woc/javax.print.attribute.standard.JobKOctetsSupported-getCategory()                                                                                                                                                                                                                                                                                                                       Get the printing attribute class which is to be used as the "category"\n for this printing attribute value.\n <P>\n For class JobKOctetsSupported, the category is class\n JobKOctetsSupported itself.\n\n @return  Printing attribute class (category), an instance of class\n          {@link java.lang.Class java.lang.Class}.
# http://rdf.webofcode.org/woc/java.awt.Event-Event(java.lang.Object-long-int-int-int-int-int)-parameter-1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              the time stamp.
# http://rdf.webofcode.org/woc/java.time.format.DateTimeFormatter-DateTimeFormatter(java.time.format.DateTimeFormatterBuilder$CompositePrinterParser-java.util.Locale-java.time.format.DecimalStyle-java.time.format.ResolverStyle-java.util.Set-java.time.chrono.Chronology-java.time.ZoneId)-parameter-6                                                                                                                                                                                                                                                                                                                                                                                                        the zone to use, null for no override
# http://rdf.webofcode.org/woc/javax.swing.text.View-paint(java.awt.Graphics-java.awt.Shape)-parameter-0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   the rendering surface to use
# http://rdf.webofcode.org/woc/java.awt.geom.Ellipse2D$Float-isEmpty()                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {@inheritDoc}\n @since 1.2
# http://rdf.webofcode.org/woc/javax.swing.DefaultBoundedRangeModel-fireStateChanged()                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Runs each <code>ChangeListener</code>'s <code>stateChanged</code> method.\n\n @see #setRangeProperties\n @see EventListenerList
# http://rdf.webofcode.org/woc/javax.security.sasl.RealmChoiceCallback-RealmChoiceCallback(java.lang.String-java.lang.String[]-int-boolean)-parameter-2                                                                                                                                                                                                                                                                                                                                                                                                                                                               the choice to be used as the default choice when the list of choices is displayed. It is an index into the {@code choices} array.
# http://rdf.webofcode.org/woc/javax.crypto.SecretKeyFactory-getInstance(java.lang.String-java.lang.String)-parameter-0                                                                                                                                                                                                                                                                                                               the standard name of the requested secret-key algorithm. See the SecretKeyFactory section in the <a href= "{@docRoot}/../technotes/guides/security/StandardNames.html#SecretKeyFactory"> Java Cryptography Architecture Standard Algorithm Name Documentation</a> for information about standard algorithm names.
#
#                                                                                                                                                                                                                                                                                                                                                                            rdfs:comment{Literal}(xsd:string)  \
# http://rdf.webofcode.org/woc/java.awt.RenderingHints-VALUE_FRACTIONALMETRICS_OFF                                                                                                                                                                                                                                                                                                                         NaN
# http://rdf.webofcode.org/woc/java.util.concurrent.ForkJoinPool-hasQueuedSubmissions()                                                                                                                                                                                                                                                                       {@code true} if there are any queued submissions
# http://rdf.webofcode.org/woc/javax.swing.event.UndoableEditEvent-getEdit()                                                                                                                                                                                                                                                                                    the UndoableEdit object encapsulating the edit
# http://rdf.webofcode.org/woc/java.text.CollationElementIterator-getMaxExpansion(int)                                                                                                                                                                                                                                          the maximum length of any expansion sequences ending with the specified order.
# http://rdf.webofcode.org/woc/javax.swing.RowSorter-modelStructureChanged()                                                                                                                                                                                                                                                                                                                               NaN
# http://rdf.webofcode.org/woc/java.util.Calendar-isSet(int)                                                                                                                                                                                                                                                      <code>true</code> if the given calendar field has a value set; <code>false</code> otherwise.
# http://rdf.webofcode.org/woc/java.nio.file.spi.FileSystemProvider-delete(java.nio.file.Path)-parameter-0                                                                                                                                                                                                                                                                                                 NaN
# http://rdf.webofcode.org/woc/javax.swing.JInternalFrame-rootPaneCheckingEnabled                                                                                                                                                                                                                                                                                                                          NaN
# http://rdf.webofcode.org/woc/javax.swing.border.TitledBorder-TOP                                                                                                                                                                                                                                                                                                                                         NaN
# http://rdf.webofcode.org/woc/javax.swing.plaf.metal.MetalIconFactory$TreeFolderIcon                                                                                                                                                                                                                                                                                                                      NaN
# ...                                                                                                                                                                                                                                                                                                                                                                                                      ...
# http://rdf.webofcode.org/woc/java.util.regex.Pattern-compile()                                                                                                                                                                                                                                                                                                                                           NaN
# http://rdf.webofcode.org/woc/java.lang.ThreadLocal$ThreadLocalMap-expungeStaleEntries()                                                                                                                                                                                                                                                                                                                  NaN
# http://rdf.webofcode.org/woc/javax.print.attribute.standard.JobKOctetsSupported-getCategory()                                                                                                                                                                                                             Printing attribute class (category), an instance of class {@link java.lang.Class java.lang.Class}.
# http://rdf.webofcode.org/woc/java.awt.Event-Event(java.lang.Object-long-int-int-int-int-int)-parameter-1                                                                                                                                                                                                                                                                                                 NaN
# http://rdf.webofcode.org/woc/java.time.format.DateTimeFormatter-DateTimeFormatter(java.time.format.DateTimeFormatterBuilder$CompositePrinterParser-java.util.Locale-java.time.format.DecimalStyle-java.time.format.ResolverStyle-java.util.Set-java.time.chrono.Chronology-java.time.ZoneId)-parameter-6                                                                                                 NaN
# http://rdf.webofcode.org/woc/javax.swing.text.View-paint(java.awt.Graphics-java.awt.Shape)-parameter-0                                                                                                                                                                                                                                                                                                   NaN
# http://rdf.webofcode.org/woc/java.awt.geom.Ellipse2D$Float-isEmpty()                                                                                                                                                                                                                                                                                                                                     NaN
# http://rdf.webofcode.org/woc/javax.swing.DefaultBoundedRangeModel-fireStateChanged()                                                                                                                                                                                                                                                                                                                     NaN
# http://rdf.webofcode.org/woc/javax.security.sasl.RealmChoiceCallback-RealmChoiceCallback(java.lang.String-java.lang.String[]-int-boolean)-parameter-2                                                                                                                                                                                                                                                    NaN
# http://rdf.webofcode.org/woc/javax.crypto.SecretKeyFactory-getInstance(java.lang.String-java.lang.String)-parameter-0                                                                                                                                                                                                                                                                                    NaN
#
#                                                                                                                                                                                                                                                                                                          rdfs:comment{Literal}@en
# http://rdf.webofcode.org/woc/java.awt.RenderingHints-VALUE_FRACTIONALMETRICS_OFF                                                                                                                                                                                                                                              NaN
# http://rdf.webofcode.org/woc/java.util.concurrent.ForkJoinPool-hasQueuedSubmissions()                                                                                                                                                                                                                                         NaN
# http://rdf.webofcode.org/woc/javax.swing.event.UndoableEditEvent-getEdit()                                                                                                                                                                                                                                                    NaN
# http://rdf.webofcode.org/woc/java.text.CollationElementIterator-getMaxExpansion(int)                                                                                                                                                                                                                                          NaN
# http://rdf.webofcode.org/woc/javax.swing.RowSorter-modelStructureChanged()                                                                                                                                                                                                                                                    NaN
# http://rdf.webofcode.org/woc/java.util.Calendar-isSet(int)                                                                                                                                                                                                                                                                    NaN
# http://rdf.webofcode.org/woc/java.nio.file.spi.FileSystemProvider-delete(java.nio.file.Path)-parameter-0                                                                                                                                                                                                                      NaN
# http://rdf.webofcode.org/woc/javax.swing.JInternalFrame-rootPaneCheckingEnabled                                                                                                                                                                                                                                               NaN
# http://rdf.webofcode.org/woc/javax.swing.border.TitledBorder-TOP                                                                                                                                                                                                                                                              NaN
# http://rdf.webofcode.org/woc/javax.swing.plaf.metal.MetalIconFactory$TreeFolderIcon                                                                                                                                                                                                                                           NaN
# ...                                                                                                                                                                                                                                                                                                                           ...
# http://rdf.webofcode.org/woc/java.util.regex.Pattern-compile()                                                                                                                                                                                                                                                                NaN
# http://rdf.webofcode.org/woc/java.lang.ThreadLocal$ThreadLocalMap-expungeStaleEntries()                                                                                                                                                                                                                                       NaN
# http://rdf.webofcode.org/woc/javax.print.attribute.standard.JobKOctetsSupported-getCategory()                                                                                                                                                                                                                                 NaN
# http://rdf.webofcode.org/woc/java.awt.Event-Event(java.lang.Object-long-int-int-int-int-int)-parameter-1                                                                                                                                                                                                                      NaN
# http://rdf.webofcode.org/woc/java.time.format.DateTimeFormatter-DateTimeFormatter(java.time.format.DateTimeFormatterBuilder$CompositePrinterParser-java.util.Locale-java.time.format.DecimalStyle-java.time.format.ResolverStyle-java.util.Set-java.time.chrono.Chronology-java.time.ZoneId)-parameter-6                      NaN
# http://rdf.webofcode.org/woc/javax.swing.text.View-paint(java.awt.Graphics-java.awt.Shape)-parameter-0                                                                                                                                                                                                                        NaN
# http://rdf.webofcode.org/woc/java.awt.geom.Ellipse2D$Float-isEmpty()                                                                                                                                                                                                                                                          NaN
# http://rdf.webofcode.org/woc/javax.swing.DefaultBoundedRangeModel-fireStateChanged()                                                                                                                                                                                                                                          NaN
# http://rdf.webofcode.org/woc/javax.security.sasl.RealmChoiceCallback-RealmChoiceCallback(java.lang.String-java.lang.String[]-int-boolean)-parameter-2                                                                                                                                                                         NaN
# http://rdf.webofcode.org/woc/javax.crypto.SecretKeyFactory-getInstance(java.lang.String-java.lang.String)-parameter-0                                                                                                                                                                                                         NaN
#
# [8726 rows x 3 columns]

# %%
#Use the index as a column that is the name of the function 
df.reset_index(level=0, inplace=True)

# %%
#Getting a sample of db for testing
data = df.sample(frac = 0.2)
data
# Out:
#                                                                                                                                              index  \
# 1244                                             http://rdf.webofcode.org/woc/java.util.prefs.Preferences-putInt(java.lang.String-int)-parameter-0
# 324                    http://rdf.webofcode.org/woc/javax.imageio.ImageWriter-prepareWriteSequence(javax.imageio.metadata.IIOMetadata)-parameter-0
# 4423        http://rdf.webofcode.org/woc/javax.security.cert.CertificateExpiredException-CertificateExpiredException(java.lang.String)-parameter-0
# 5699                                                                                http://rdf.webofcode.org/woc/java.io.CharArrayReader-mark(int)
# 6233  http://rdf.webofcode.org/woc/javax.xml.crypto.dsig.spec.XSLTTransformParameterSpec-XSLTTransformParameterSpec(javax.xml.crypto.XMLStructure)
# 4549                                              http://rdf.webofcode.org/woc/java.io.FileOutputStream-open(java.lang.String-boolean)-parameter-0
# 3643                                                         http://rdf.webofcode.org/woc/java.util.Arrays-equals(boolean[]-boolean[])-parameter-0
# 1255                                      http://rdf.webofcode.org/woc/java.sql.ResultSet-updateArray(java.lang.String-java.sql.Array)-parameter-1
# 521                          http://rdf.webofcode.org/woc/java.util.JapaneseImperialCalendar-getYearOffsetInMillis(sun.util.calendar.CalendarDate)
# 3613                                                     http://rdf.webofcode.org/woc/java.sql.ParameterMetaData-getParameterType(int)-parameter-0
# ...                                                                                                                                            ...
# 7748                                            http://rdf.webofcode.org/woc/javax.swing.text.Keymap-removeKeyStrokeBinding(javax.swing.KeyStroke)
# 2024                                                                          http://rdf.webofcode.org/woc/java.lang.Math-cosh(double)-parameter-0
# 4555                                                                  http://rdf.webofcode.org/woc/java.awt.font.NumericShaper$Range-TAI_THAM_HORA
# 7565                                   http://rdf.webofcode.org/woc/java.time.chrono.ChronoLocalDateTime-with(java.time.temporal.TemporalAdjuster)
# 1596                                                http://rdf.webofcode.org/woc/javax.crypto.Cipher-update(byte[]-int-int-byte[]-int)-parameter-1
# 4324                             http://rdf.webofcode.org/woc/jdk.internal.org.objectweb.asm.util.Printer-visit(java.lang.String-java.lang.Object)
# 5317                                    http://rdf.webofcode.org/woc/javax.imageio.stream.ImageOutputStream-writeChars(char[]-int-int)-parameter-2
# 292                                                                   http://rdf.webofcode.org/woc/java.util.concurrent.ConcurrentLinkedDeque-tail
# 5222                                                      http://rdf.webofcode.org/woc/javax.swing.AbstractButton-setSelected(boolean)-parameter-0
# 8348                                  http://rdf.webofcode.org/woc/java.io.ObjectOutputStream-writeNonProxyDesc(java.io.ObjectStreamClass-boolean)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    rdfs:comment{Literal}  \
# 1244                                                                                                                                                                                                                                                                                                                                                                                                                                                        key with which the string form of value is to be associated.
# 324                                                                                                                                                                                                                                                                                                                                                                                                                                                                      A stream metadata object, or <code>null</code>.
# 4423                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 the detail message.
# 5699  Marks the present position in the stream.  Subsequent calls to reset()\n will reposition the stream to this point.\n\n @param  readAheadLimit  Limit on the number of characters that may be\n                         read while still preserving the mark.  Because\n                         the stream's input comes from a character array,\n                         there is no actual limit; hence this argument is\n                         ignored.\n\n @exception  IOException  If an I/O error occurs
# 6233                                                                                                                                                                                                                                                                                        Creates an <code>XSLTTransformParameterSpec</code> with the specified\n stylesheet.\n\n @param stylesheet the XSLT stylesheet to be used\n @throws NullPointerException if <code>stylesheet</code> is\n    <code>null</code>
# 4549                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           name of file to be opened
# 3643                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 one array to be tested for equality
# 1255                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                the new column value
# 521                                                                                                                                                                                                                                                                                       Returns the millisecond offset from the beginning of the\n year. In the year for Long.MIN_VALUE, it's a pseudo value\n beyond the limit. The given CalendarDate object must have been\n normalized before calling this method.
# 3613                                                                                                                                                                                                                                                                                                                                                                                                                                                                      the first parameter is 1, the second is 2, ...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 7748                                                                                                                                                                                                                                                                                                                                                                                                                                                 Removes a binding from the keymap.\n\n @param keys the key sequence
# 2024                                                                                                                                                                                                                                                                                                                                                                                                                                                               The number whose hyperbolic cosine is to be returned.
# 4555                                                                                                                                                                                                                                                                                                                                                                                                                                                              The Tai Tham Hora range with the Tai Tham Hora digits.
# 7565                                                                                                                                                                                                                                                                                                                                                                                                                 {@inheritDoc}\n @throws DateTimeException {@inheritDoc}\n @throws ArithmeticException {@inheritDoc}
# 1596                                                                                                                                                                                                                                                                                                                                                                                                                                                             the offset in <code>input</code> where the input starts
# 4324                                                                                                                                                                                                                                                                                                                                                                                                                               Annotation value. See {@link jdk.internal.org.objectweb.asm.AnnotationVisitor#visit}.
# 5317                                                                                                                                                                                                                                                                                                                                                                                                                                                                          the number of <code>char</code>s to write.
# 292                          A node from which the last node on list (that is, the unique node p\n with p.next == null && p.prev != p) can be reached in O(1) time.\n Invariants:\n - the last node is always O(1) reachable from tail via next links\n - all live nodes are reachable from the last node via pred()\n - tail != null\n - tail is never gc-unlinked (but may be unlinked)\n Non-invariants:\n - tail.item may or may not be null\n - tail may not be reachable from the first or last node, or from head
# 5222                                                                                                                                                                                                                                                                                                                                                                                                                                                                     true if the button is selected, otherwise false
# 8348                                                                                                                                                                                                                                                                                                                                                                                                                      Writes class descriptor representing a standard (i.e., not a dynamic\n proxy) class to stream.
#
#      rdfs:comment{Literal}(xsd:string) rdfs:comment{Literal}@en
# 1244                               NaN                      NaN
# 324                                NaN                      NaN
# 4423                               NaN                      NaN
# 5699                               NaN                      NaN
# 6233                               NaN                      NaN
# 4549                               NaN                      NaN
# 3643                               NaN                      NaN
# 1255                               NaN                      NaN
# 521                                NaN                      NaN
# 3613                               NaN                      NaN
# ...                                ...                      ...
# 7748                               NaN                      NaN
# 2024                               NaN                      NaN
# 4555                               NaN                      NaN
# 7565                               NaN                      NaN
# 1596                               NaN                      NaN
# 4324                               NaN                      NaN
# 5317                               NaN                      NaN
# 292                                NaN                      NaN
# 5222                               NaN                      NaN
# 8348                               NaN                      NaN
#
# [1745 rows x 4 columns]

# %%
#Renaming columns names 
data.rename({'index': 'function', 'rdfs:comment{Literal}' : 'description', 'rdfs:comment{Literal}(xsd:string)' : 'return_value', 'rdfs:comment{Literal}@en' : 'description3' }, axis=1, inplace=True)
#Leave only the row where the function is really a function so the line is ending with ')'
data = data.loc[(data['function'].str.endswith(')'))]

data.function
# Out:
# 5699                                                                                                    http://rdf.webofcode.org/woc/java.io.CharArrayReader-mark(int)
# 6233                      http://rdf.webofcode.org/woc/javax.xml.crypto.dsig.spec.XSLTTransformParameterSpec-XSLTTransformParameterSpec(javax.xml.crypto.XMLStructure)
# 521                                              http://rdf.webofcode.org/woc/java.util.JapaneseImperialCalendar-getYearOffsetInMillis(sun.util.calendar.CalendarDate)
# 2496                                                                                 http://rdf.webofcode.org/woc/java.nio.channels.DatagramChannel-getRemoteAddress()
# 1835    http://rdf.webofcode.org/woc/javax.swing.plaf.nimbus.SynthPainterImpl-paintButtonBorder(javax.swing.plaf.synth.SynthContext-java.awt.Graphics-int-int-int-int)
# 3530                                                                         http://rdf.webofcode.org/woc/java.io.StreamTokenizer-StreamTokenizer(java.io.InputStream)
# 814                                                                              http://rdf.webofcode.org/woc/javax.security.auth.callback.TextInputCallback-getText()
# 3348                                                 http://rdf.webofcode.org/woc/java.awt.List$AccessibleAWTList$AccessibleAWTListChild-setBackground(java.awt.Color)
# 1030                                                                     http://rdf.webofcode.org/woc/jdk.internal.org.objectweb.asm.Type-getArgumentsAndReturnSizes()
# 4986                                                                                 http://rdf.webofcode.org/woc/java.util.concurrent.ThreadLocalRandom-nextBoolean()
#                                                                                      ...
# 973                                                                              http://rdf.webofcode.org/woc/javax.crypto.CryptoPermissions-load(java.io.InputStream)
# 6100                                                                                         http://rdf.webofcode.org/woc/javax.imageio.ImageReader-getTileHeight(int)
# 1210                                                                     http://rdf.webofcode.org/woc/javax.print.attribute.Size2DSyntax-Size2DSyntax(float-float-int)
# 7526                                                                       http://rdf.webofcode.org/woc/javax.swing.text.StyleContext$FontKey-equals(java.lang.Object)
# 2136                                                                                                       http://rdf.webofcode.org/woc/javax.naming.Reference-clone()
# 3943                                                                                   http://rdf.webofcode.org/woc/javax.imageio.ImageWriteParam-getTileGridXOffset()
# 7748                                                                http://rdf.webofcode.org/woc/javax.swing.text.Keymap-removeKeyStrokeBinding(javax.swing.KeyStroke)
# 7565                                                       http://rdf.webofcode.org/woc/java.time.chrono.ChronoLocalDateTime-with(java.time.temporal.TemporalAdjuster)
# 4324                                                 http://rdf.webofcode.org/woc/jdk.internal.org.objectweb.asm.util.Printer-visit(java.lang.String-java.lang.Object)
# 8348                                                      http://rdf.webofcode.org/woc/java.io.ObjectOutputStream-writeNonProxyDesc(java.io.ObjectStreamClass-boolean)
# Name: function, Length: 783, dtype: object

# %%
#Delete the rows where the function name contains parameter since that rows aren't defintion of functions 
data = data[~data.function.str.contains("parameter")]
data
# Out:
#                                                                                                                                                             function  \
# 5699                                                                                                  http://rdf.webofcode.org/woc/java.io.CharArrayReader-mark(int)
# 6233                    http://rdf.webofcode.org/woc/javax.xml.crypto.dsig.spec.XSLTTransformParameterSpec-XSLTTransformParameterSpec(javax.xml.crypto.XMLStructure)
# 521                                            http://rdf.webofcode.org/woc/java.util.JapaneseImperialCalendar-getYearOffsetInMillis(sun.util.calendar.CalendarDate)
# 2496                                                                               http://rdf.webofcode.org/woc/java.nio.channels.DatagramChannel-getRemoteAddress()
# 1835  http://rdf.webofcode.org/woc/javax.swing.plaf.nimbus.SynthPainterImpl-paintButtonBorder(javax.swing.plaf.synth.SynthContext-java.awt.Graphics-int-int-int-int)
# 3530                                                                       http://rdf.webofcode.org/woc/java.io.StreamTokenizer-StreamTokenizer(java.io.InputStream)
# 814                                                                            http://rdf.webofcode.org/woc/javax.security.auth.callback.TextInputCallback-getText()
# 3348                                               http://rdf.webofcode.org/woc/java.awt.List$AccessibleAWTList$AccessibleAWTListChild-setBackground(java.awt.Color)
# 1030                                                                   http://rdf.webofcode.org/woc/jdk.internal.org.objectweb.asm.Type-getArgumentsAndReturnSizes()
# 4986                                                                               http://rdf.webofcode.org/woc/java.util.concurrent.ThreadLocalRandom-nextBoolean()
# ...                                                                                                                                                              ...
# 973                                                                            http://rdf.webofcode.org/woc/javax.crypto.CryptoPermissions-load(java.io.InputStream)
# 6100                                                                                       http://rdf.webofcode.org/woc/javax.imageio.ImageReader-getTileHeight(int)
# 1210                                                                   http://rdf.webofcode.org/woc/javax.print.attribute.Size2DSyntax-Size2DSyntax(float-float-int)
# 7526                                                                     http://rdf.webofcode.org/woc/javax.swing.text.StyleContext$FontKey-equals(java.lang.Object)
# 2136                                                                                                     http://rdf.webofcode.org/woc/javax.naming.Reference-clone()
# 3943                                                                                 http://rdf.webofcode.org/woc/javax.imageio.ImageWriteParam-getTileGridXOffset()
# 7748                                                              http://rdf.webofcode.org/woc/javax.swing.text.Keymap-removeKeyStrokeBinding(javax.swing.KeyStroke)
# 7565                                                     http://rdf.webofcode.org/woc/java.time.chrono.ChronoLocalDateTime-with(java.time.temporal.TemporalAdjuster)
# 4324                                               http://rdf.webofcode.org/woc/jdk.internal.org.objectweb.asm.util.Printer-visit(java.lang.String-java.lang.Object)
# 8348                                                    http://rdf.webofcode.org/woc/java.io.ObjectOutputStream-writeNonProxyDesc(java.io.ObjectStreamClass-boolean)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                description  \
# 5699                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Marks the present position in the stream.  Subsequent calls to reset()\n will reposition the stream to this point.\n\n @param  readAheadLimit  Limit on the number of characters that may be\n                         read while still preserving the mark.  Because\n                         the stream's input comes from a character array,\n                         there is no actual limit; hence this argument is\n                         ignored.\n\n @exception  IOException  If an I/O error occurs
# 6233                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Creates an <code>XSLTTransformParameterSpec</code> with the specified\n stylesheet.\n\n @param stylesheet the XSLT stylesheet to be used\n @throws NullPointerException if <code>stylesheet</code> is\n    <code>null</code>
# 521                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Returns the millisecond offset from the beginning of the\n year. In the year for Long.MIN_VALUE, it's a pseudo value\n beyond the limit. The given CalendarDate object must have been\n normalized before calling this method.
# 2496                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Returns the remote address to which this channel's socket is connected.\n\n @return  The remote address; {@code null} if the channel's socket is not\n          connected\n\n @throws  ClosedChannelException\n          If the channel is closed\n @throws  IOException\n          If an I/O error occurs\n\n @since 1.7
# 1835                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Paints the border of a button.\n\n @param context SynthContext identifying the <code>JComponent</code> and\n        <code>Region</code> to paint to\n @param g <code>Graphics</code> to paint to\n @param x X coordinate of the area to paint to\n @param y Y coordinate of the area to paint to\n @param w Width of the area to paint to\n @param h Height of the area to paint to
# 3530  Creates a stream tokenizer that parses the specified input\n stream. The stream tokenizer is initialized to the following\n default state:\n <ul>\n <li>All byte values {@code 'A'} through {@code 'Z'},\n     {@code 'a'} through {@code 'z'}, and\n     {@code '\u00A0'} through {@code '\u00FF'} are\n     considered to be alphabetic.\n <li>All byte values {@code '\u0000'} through\n     {@code '\u0020'} are considered to be white space.\n <li>{@code '/'} is a comment character.\n <li>Single quote {@code '\''} and double quote {@code '"'}\n     are string quote characters.\n <li>Numbers are parsed.\n <li>Ends of lines are treated as white space, not as separate tokens.\n <li>C-style and C++-style comments are not recognized.\n </ul>\n\n @deprecated As of JDK version 1.1, the preferred way to tokenize an\n input stream is to convert it into a character stream, for example:\n <blockquote><pre>\n   Reader r = new BufferedReader(new InputStreamReader(is));\n   StreamTokenizer st = new StreamTokenizer(r);\n </pre></blockquote>\n\n @param      is        an input stream.\n @see        java.io.BufferedReader\n @see        java.io.InputStreamReader\n @see        java.io.StreamTokenizer#StreamTokenizer(java.io.Reader)
# 814                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Get the retrieved text.\n\n <p>\n\n @return the retrieved text, which may be null.\n\n @see #setText
# 3348                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Set the background color of this object.\n\n @param c the new Color for the background\n @see #setBackground
# 1030                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Returns the size of the arguments and of the return value of methods of\n this type. This method should only be used for method types.\n\n @return the size of the arguments (plus one for the implicit this\n         argument), argSize, and the size of the return value, retSize,\n         packed into a single\n         int i = <tt>(argSize &lt;&lt; 2) | retSize</tt>\n         (argSize is therefore equal to <tt>i &gt;&gt; 2</tt>,\n         and retSize to <tt>i &amp; 0x03</tt>).
# 4986                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Returns a pseudorandom {@code boolean} value.\n\n @return a pseudorandom {@code boolean} value
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 973                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Populates the crypto policy from the specified\n InputStream into this CryptoPermissions object.\n\n @param in the InputStream to load from.\n\n @exception SecurityException if cannot load\n successfully.
# 6100                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Returns the height of a tile in the given image.\n\n <p> The default implementation simply returns\n <code>getHeight(imageIndex)</code>, which is correct for\n non-tiled images.  Readers that support tiling should override\n this method.\n\n @return the height of a tile.\n\n @param imageIndex the index of the image to be queried.\n\n @exception IllegalStateException if the input source has not been set.\n @exception IndexOutOfBoundsException if the supplied index is\n out of bounds.\n @exception IOException if an error occurs during reading.
# 1210                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Construct a new two-dimensional size attribute from the given\n floating-point values.\n\n @param  x  X dimension.\n @param  y  Y dimension.\n @param  units\n     Unit conversion factor, e.g. {@link #INCH INCH} or\n     {@link #MM MM}.\n\n @exception  IllegalArgumentException\n     (Unchecked exception) Thrown if {@code x < 0} or {@code y < 0} or\n     {@code units < 1}.
# 7526                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Compares this object to the specified object.\n The result is <code>true</code> if and only if the argument is not\n <code>null</code> and is a <code>Font</code> object with the same\n name, style, and point size as this font.\n @param     obj   the object to compare this font with.\n @return    <code>true</code> if the objects are equal;\n            <code>false</code> otherwise.
# 2136                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Makes a copy of this reference using its class name\n list of addresses, class factory name and class factory location.\n Changes to the newly created copy does not affect this Reference\n and vice versa.
# 3943                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Returns the horizontal tile grid offset of an image as it will\n be written to the output stream.  If tiling parameters have not\n been set, an <code>IllegalStateException</code> is thrown.\n\n @return the tile grid X offset to be used for encoding.\n\n @exception UnsupportedOperationException if the plug-in does not\n support tiling.\n @exception IllegalStateException if the tiling mode is not\n <code>MODE_EXPLICIT</code>.\n @exception IllegalStateException if the tiling parameters have\n not been set.\n\n @see #setTiling(int, int, int, int)\n @see #getTileGridYOffset()
# 7748                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Removes a binding from the keymap.\n\n @param keys the key sequence
# 7565                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {@inheritDoc}\n @throws DateTimeException {@inheritDoc}\n @throws ArithmeticException {@inheritDoc}
# 4324                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Annotation value. See {@link jdk.internal.org.objectweb.asm.AnnotationVisitor#visit}.
# 8348                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Writes class descriptor representing a standard (i.e., not a dynamic\n proxy) class to stream.
#
#                                                                                                                                                                                                                                                                                     return_value  \
# 5699                                                                                                                                                                                                                                                                                         NaN
# 6233                                                                                                                                                                                                                                                                                         NaN
# 521                                                                                                                                                                                                                                                                                          NaN
# 2496                                                                                                                                                                                                                   The remote address; {@code null} if the channel's socket is not connected
# 1835                                                                                                                                                                                                                                                                                         NaN
# 3530                                                                                                                                                                                                                                                                                         NaN
# 814                                                                                                                                                                                                                                                       the retrieved text, which may be null.
# 3348                                                                                                                                                                                                                                                                                         NaN
# 1030  the size of the arguments (plus one for the implicit this argument), argSize, and the size of the return value, retSize, packed into a single int i = <tt>(argSize &lt;&lt; 2) | retSize</tt> (argSize is therefore equal to <tt>i &gt;&gt; 2</tt>, and retSize to <tt>i &amp; 0x03</tt>).
# 4986                                                                                                                                                                                                                                                        a pseudorandom {@code boolean} value
# ...                                                                                                                                                                                                                                                                                          ...
# 973                                                                                                                                                                                                                                                                                          NaN
# 6100                                                                                                                                                                                                                                                                       the height of a tile.
# 1210                                                                                                                                                                                                                                                                                         NaN
# 7526                                                                                                                                                                                                                   <code>true</code> if the objects are equal; <code>false</code> otherwise.
# 2136                                                                                                                                                                                                                                                                                         NaN
# 3943                                                                                                                                                                                                                                             the tile grid X offset to be used for encoding.
# 7748                                                                                                                                                                                                                                                                                         NaN
# 7565                                                                                                                                                                                                                                                                                         NaN
# 4324                                                                                                                                                                                                                                                                                         NaN
# 8348                                                                                                                                                                                                                                                                                         NaN
#
#      description3
# 5699          NaN
# 6233          NaN
# 521           NaN
# 2496          NaN
# 1835          NaN
# 3530          NaN
# 814           NaN
# 3348          NaN
# 1030          NaN
# 4986          NaN
# ...           ...
# 973           NaN
# 6100          NaN
# 1210          NaN
# 7526          NaN
# 2136          NaN
# 3943          NaN
# 7748          NaN
# 7565          NaN
# 4324          NaN
# 8348          NaN
#
# [782 rows x 4 columns]

# %%
preprocessing.clean_ontology(data)
data
# Out:
#                                                                                                                                function  \
# 5699                                                                                                  java.io.CharArrayReader-mark(int)
# 6233                    javax.xml.crypto.dsig.spec.XSLTTransformParameterSpec-XSLTTransformParameterSpec(javax.xml.crypto.XMLStructure)
# 521                                            java.util.JapaneseImperialCalendar-getYearOffsetInMillis(sun.util.calendar.CalendarDate)
# 2496                                                                               java.nio.channels.DatagramChannel-getRemoteAddress()
# 1835  javax.swing.plaf.nimbus.SynthPainterImpl-paintButtonBorder(javax.swing.plaf.synth.SynthContext-java.awt.Graphics-int-int-int-int)
# 3530                                                                       java.io.StreamTokenizer-StreamTokenizer(java.io.InputStream)
# 814                                                                            javax.security.auth.callback.TextInputCallback-getText()
# 3348                                               java.awt.List$AccessibleAWTList$AccessibleAWTListChild-setBackground(java.awt.Color)
# 1030                                                                   jdk.internal.org.objectweb.asm.Type-getArgumentsAndReturnSizes()
# 4986                                                                               java.util.concurrent.ThreadLocalRandom-nextBoolean()
# ...                                                                                                                                 ...
# 973                                                                            javax.crypto.CryptoPermissions-load(java.io.InputStream)
# 6100                                                                                       javax.imageio.ImageReader-getTileHeight(int)
# 1210                                                                   javax.print.attribute.Size2DSyntax-Size2DSyntax(float-float-int)
# 7526                                                                     javax.swing.text.StyleContext$FontKey-equals(java.lang.Object)
# 2136                                                                                                     javax.naming.Reference-clone()
# 3943                                                                                 javax.imageio.ImageWriteParam-getTileGridXOffset()
# 7748                                                              javax.swing.text.Keymap-removeKeyStrokeBinding(javax.swing.KeyStroke)
# 7565                                                     java.time.chrono.ChronoLocalDateTime-with(java.time.temporal.TemporalAdjuster)
# 4324                                               jdk.internal.org.objectweb.asm.util.Printer-visit(java.lang.String-java.lang.Object)
# 8348                                                    java.io.ObjectOutputStream-writeNonProxyDesc(java.io.ObjectStreamClass-boolean)
#
#                                                                                                                                                                                                                           description  \
# 5699                                                                                                             Marks the present position in the stream.  Subsequent calls to reset()  will reposition the stream to this point.
# 6233                                                                                                                                                     Creates an XSLTTransform mParameter rSpec with the specified  stylesheet.
# 521     Returns the millisecond offset from the beginning of the  year. In the year for Long.MIN_VALUE, it's a pseudo value  beyond the limit. The given Calendar rDate object must have been  normalized before calling this method.
# 2496                                                                                                                                                       Returns the remote address to which this channel's socket is connected.
# 1835                                                                                                                                                                                                Paints the border of a button.
# 3530
# 814                                                                                                                                                                                                     Get the retrieved text.
# 3348                                                                                                                                                                                      Set the background color of this object.
# 1030                                                                                         Returns the size of the arguments and of the return value of methods of  this type. This method should only be used for method types.
# 4986
# ...                                                                                                                                                                                                                               ...
# 973                                                                                                                            Populates the crypto policy from the specified  Input tStream into this Crypto oPermissions object.
# 6100  Returns the height of a tile in the given image.    The default implementation simply returns  get tHeight(image eIndex), which is correct for  non-tiled images.  Readers that support tiling should override  this method.
# 1210                                                                                                                                         Construct a new two-dimensional size attribute from the given  floating-point values.
# 7526                                       Compares this object to the specified object.  The result is true if and only if the argument is not  null and is a Font object with the same  name, style, and point size as this font.
# 2136                        Makes a copy of this reference using its class name  list of addresses, class factory name and class factory location.  Changes to the newly created copy does not affect this Reference  and vice versa.
# 3943                                            Returns the horizontal tile grid offset of an image as it will  be written to the output stream.  If tiling parameters have not  been set, an Illegal lState eException is thrown.
# 7748                                                                                                                                                                                            Removes a binding from the keymap.
# 7565
# 4324
# 8348                                                                                                                                    Writes class descriptor representing a standard (i.e., not a dynamic  proxy) class to stream.
#
#                                                                                                                                                                                                                                                          return_value  \
# 5699                                                                                                                                                                                                                                                              NaN
# 6233                                                                                                                                                                                                                                                              NaN
# 521                                                                                                                                                                                                                                                               NaN
# 2496                                                                                                                                                                                        The remote address; {@code null} if the channel's socket is not connected
# 1835                                                                                                                                                                                                                                                              NaN
# 3530                                                                                                                                                                                                                                                              NaN
# 814                                                                                                                                                                                                                            the retrieved text, which may be null.
# 3348                                                                                                                                                                                                                                                              NaN
# 1030  the size of the arguments (plus one for the implicit this argument), argSize, and the size of the return value, retSize, packed into a single int i = (argSize &lt;&lt; 2) | retSize (argSize is therefore equal to i &gt;&gt; 2, and retSize to i &amp; 0x03).
# 4986                                                                                                                                                                                                                             a pseudorandom {@code boolean} value
# ...                                                                                                                                                                                                                                                               ...
# 973                                                                                                                                                                                                                                                               NaN
# 6100                                                                                                                                                                                                                                            the height of a tile.
# 1210                                                                                                                                                                                                                                                              NaN
# 7526                                                                                                                                                                                                                  true if the objects are equal; false otherwise.
# 2136                                                                                                                                                                                                                                                              NaN
# 3943                                                                                                                                                                                                                  the tile grid X offset to be used for encoding.
# 7748                                                                                                                                                                                                                                                              NaN
# 7565                                                                                                                                                                                                                                                              NaN
# 4324                                                                                                                                                                                                                                                              NaN
# 8348                                                                                                                                                                                                                                                              NaN
#
#      description3
# 5699          NaN
# 6233          NaN
# 521           NaN
# 2496          NaN
# 1835          NaN
# 3530          NaN
# 814           NaN
# 3348          NaN
# 1030          NaN
# 4986          NaN
# ...           ...
# 973           NaN
# 6100          NaN
# 1210          NaN
# 7526          NaN
# 2136          NaN
# 3943          NaN
# 7748          NaN
# 7565          NaN
# 4324          NaN
# 8348          NaN
#
# [782 rows x 4 columns]

# %%
#count rows where due to preprocessing the description became an empty string
data[data['description'] == ''].index
# Out:
# Int64Index([3530, 4986, 6807,   16, 8047, 5657,  876, 3193, 1026, 5179,
#             ...
#              160, 5203, 7131, 7549,  712, 1060, 5458, 6747, 7565, 4324],
#            dtype='int64', length=209)

# %%
#delete rows where due to preprocessing the description became an empty string
data = data[data['description'] != '']
data
# Out:
#                                                                                                                                function  \
# 5699                                                                                                  java.io.CharArrayReader-mark(int)
# 6233                    javax.xml.crypto.dsig.spec.XSLTTransformParameterSpec-XSLTTransformParameterSpec(javax.xml.crypto.XMLStructure)
# 521                                            java.util.JapaneseImperialCalendar-getYearOffsetInMillis(sun.util.calendar.CalendarDate)
# 2496                                                                               java.nio.channels.DatagramChannel-getRemoteAddress()
# 1835  javax.swing.plaf.nimbus.SynthPainterImpl-paintButtonBorder(javax.swing.plaf.synth.SynthContext-java.awt.Graphics-int-int-int-int)
# 814                                                                            javax.security.auth.callback.TextInputCallback-getText()
# 3348                                               java.awt.List$AccessibleAWTList$AccessibleAWTListChild-setBackground(java.awt.Color)
# 1030                                                                   jdk.internal.org.objectweb.asm.Type-getArgumentsAndReturnSizes()
# 8188                                       javax.swing.text.StyleContext$NamedStyle-addChangeListener(javax.swing.event.ChangeListener)
# 555                                                                                                 java.awt.geom.Ellipse2D-Ellipse2D()
# ...                                                                                                                                 ...
# 6206                                                                                            javax.management.PersistentMBean-load()
# 3991                                                  javax.swing.JComponent-removeAncestorListener(javax.swing.event.AncestorListener)
# 973                                                                            javax.crypto.CryptoPermissions-load(java.io.InputStream)
# 6100                                                                                       javax.imageio.ImageReader-getTileHeight(int)
# 1210                                                                   javax.print.attribute.Size2DSyntax-Size2DSyntax(float-float-int)
# 7526                                                                     javax.swing.text.StyleContext$FontKey-equals(java.lang.Object)
# 2136                                                                                                     javax.naming.Reference-clone()
# 3943                                                                                 javax.imageio.ImageWriteParam-getTileGridXOffset()
# 7748                                                              javax.swing.text.Keymap-removeKeyStrokeBinding(javax.swing.KeyStroke)
# 8348                                                    java.io.ObjectOutputStream-writeNonProxyDesc(java.io.ObjectStreamClass-boolean)
#
#                                                                                                                                                                                                                                                                                                               description  \
# 5699                                                                                                                                                                                                 Marks the present position in the stream.  Subsequent calls to reset()  will reposition the stream to this point.
# 6233                                                                                                                                                                                                                                         Creates an XSLTTransform mParameter rSpec with the specified  stylesheet.
# 521                                                                                         Returns the millisecond offset from the beginning of the  year. In the year for Long.MIN_VALUE, it's a pseudo value  beyond the limit. The given Calendar rDate object must have been  normalized before calling this method.
# 2496                                                                                                                                                                                                                                           Returns the remote address to which this channel's socket is connected.
# 1835                                                                                                                                                                                                                                                                                    Paints the border of a button.
# 814                                                                                                                                                                                                                                                                                         Get the retrieved text.
# 3348                                                                                                                                                                                                                                                                          Set the background color of this object.
# 1030                                                                                                                                                                             Returns the size of the arguments and of the return value of methods of  this type. This method should only be used for method types.
# 8188                                                                                                                                                                                                                                                                                           Adds a change listener.
# 555                                                   This is an abstract class that cannot be instantiated directly.  Type-specific implementation subclasses are available for  instantiation and provide a number of formats for storing  the information necessary to satisfy the various accessor  methods below.
# ...                                                                                                                                                                                                                                                                                                                   ...
# 6206  Instantiates this sMBean instance with the data found for  the MBean in the persistent store.  The data loaded could include  attribute and operation values.   This method should be called during construction or initialization of this instance,  and before the MBean is registered with the MBean nServer.
# 3991                                                                                                                                                                                                                                         Unregisters listener so that it will no longer receive  Ancestor rEvents.
# 973                                                                                                                                                                                                                Populates the crypto policy from the specified  Input tStream into this Crypto oPermissions object.
# 6100                                                                                      Returns the height of a tile in the given image.    The default implementation simply returns  get tHeight(image eIndex), which is correct for  non-tiled images.  Readers that support tiling should override  this method.
# 1210                                                                                                                                                                                                                             Construct a new two-dimensional size attribute from the given  floating-point values.
# 7526                                                                                                                           Compares this object to the specified object.  The result is true if and only if the argument is not  null and is a Font object with the same  name, style, and point size as this font.
# 2136                                                                                                            Makes a copy of this reference using its class name  list of addresses, class factory name and class factory location.  Changes to the newly created copy does not affect this Reference  and vice versa.
# 3943                                                                                                                                Returns the horizontal tile grid offset of an image as it will  be written to the output stream.  If tiling parameters have not  been set, an Illegal lState eException is thrown.
# 7748                                                                                                                                                                                                                                                                                Removes a binding from the keymap.
# 8348                                                                                                                                                                                                                        Writes class descriptor representing a standard (i.e., not a dynamic  proxy) class to stream.
#
#                                                                                                                                                                                                                                                          return_value  \
# 5699                                                                                                                                                                                                                                                              NaN
# 6233                                                                                                                                                                                                                                                              NaN
# 521                                                                                                                                                                                                                                                               NaN
# 2496                                                                                                                                                                                        The remote address; {@code null} if the channel's socket is not connected
# 1835                                                                                                                                                                                                                                                              NaN
# 814                                                                                                                                                                                                                            the retrieved text, which may be null.
# 3348                                                                                                                                                                                                                                                              NaN
# 1030  the size of the arguments (plus one for the implicit this argument), argSize, and the size of the return value, retSize, packed into a single int i = (argSize &lt;&lt; 2) | retSize (argSize is therefore equal to i &gt;&gt; 2, and retSize to i &amp; 0x03).
# 8188                                                                                                                                                                                                                                                              NaN
# 555                                                                                                                                                                                                                                                               NaN
# ...                                                                                                                                                                                                                                                               ...
# 6206                                                                                                                                                                                                                                                              NaN
# 3991                                                                                                                                                                                                                                                              NaN
# 973                                                                                                                                                                                                                                                               NaN
# 6100                                                                                                                                                                                                                                            the height of a tile.
# 1210                                                                                                                                                                                                                                                              NaN
# 7526                                                                                                                                                                                                                  true if the objects are equal; false otherwise.
# 2136                                                                                                                                                                                                                                                              NaN
# 3943                                                                                                                                                                                                                  the tile grid X offset to be used for encoding.
# 7748                                                                                                                                                                                                                                                              NaN
# 8348                                                                                                                                                                                                                                                              NaN
#
#      description3
# 5699          NaN
# 6233          NaN
# 521           NaN
# 2496          NaN
# 1835          NaN
# 814           NaN
# 3348          NaN
# 1030          NaN
# 8188          NaN
# 555           NaN
# ...           ...
# 6206          NaN
# 3991          NaN
# 973           NaN
# 6100          NaN
# 1210          NaN
# 7526          NaN
# 2136          NaN
# 3943          NaN
# 7748          NaN
# 8348          NaN
#
# [573 rows x 4 columns]

# %%
data = data[~data['description'].isna()]
data = data[~data['function'].isna()] 
descriptions = data['description']
descriptions
# Out:
# 5699                                                                                                                                                                                                   Marks the present position in the stream.  Subsequent calls to reset()  will reposition the stream to this point.
# 6233                                                                                                                                                                                                                                           Creates an XSLTTransform mParameter rSpec with the specified  stylesheet.
# 521                                                                                           Returns the millisecond offset from the beginning of the  year. In the year for Long.MIN_VALUE, it's a pseudo value  beyond the limit. The given Calendar rDate object must have been  normalized before calling this method.
# 2496                                                                                                                                                                                                                                             Returns the remote address to which this channel's socket is connected.
# 1835                                                                                                                                                                                                                                                                                      Paints the border of a button.
# 814                                                                                                                                                                                                                                                                                           Get the retrieved text.
# 3348                                                                                                                                                                                                                                                                            Set the background color of this object.
# 1030                                                                                                                                                                               Returns the size of the arguments and of the return value of methods of  this type. This method should only be used for method types.
# 8188                                                                                                                                                                                                                                                                                             Adds a change listener.
# 555                                                     This is an abstract class that cannot be instantiated directly.  Type-specific implementation subclasses are available for  instantiation and provide a number of formats for storing  the information necessary to satisfy the various accessor  methods below.
#                                                                                                                                                                ...
# 6206    Instantiates this sMBean instance with the data found for  the MBean in the persistent store.  The data loaded could include  attribute and operation values.   This method should be called during construction or initialization of this instance,  and before the MBean is registered with the MBean nServer.
# 3991                                                                                                                                                                                                                                           Unregisters listener so that it will no longer receive  Ancestor rEvents.
# 973                                                                                                                                                                                                                  Populates the crypto policy from the specified  Input tStream into this Crypto oPermissions object.
# 6100                                                                                        Returns the height of a tile in the given image.    The default implementation simply returns  get tHeight(image eIndex), which is correct for  non-tiled images.  Readers that support tiling should override  this method.
# 1210                                                                                                                                                                                                                               Construct a new two-dimensional size attribute from the given  floating-point values.
# 7526                                                                                                                             Compares this object to the specified object.  The result is true if and only if the argument is not  null and is a Font object with the same  name, style, and point size as this font.
# 2136                                                                                                              Makes a copy of this reference using its class name  list of addresses, class factory name and class factory location.  Changes to the newly created copy does not affect this Reference  and vice versa.
# 3943                                                                                                                                  Returns the horizontal tile grid offset of an image as it will  be written to the output stream.  If tiling parameters have not  been set, an Illegal lState eException is thrown.
# 7748                                                                                                                                                                                                                                                                                  Removes a binding from the keymap.
# 8348                                                                                                                                                                                                                          Writes class descriptor representing a standard (i.e., not a dynamic  proxy) class to stream.
# Name: description, Length: 573, dtype: object

# %%
#Clearing text 
descriptions_processed = descriptions.apply(lambda x: preprocessing.clear_text(x,"w2v"))
descriptions_processed
# Out:
# 5699                                                                                                                             marks present position stream subsequent calls reset reposition stream point
# 6233                                                                                                                                              creates xslttransform mparameter rspec specified stylesheet
# 521                                                        returns millisecond offset beginning year year long min value pseudo value beyond limit given calendar rdate object must normalized calling method
# 2496                                                                                                                                                          returns remote address channel socket connected
# 1835                                                                                                                                                                                     paints border button
# 814                                                                                                                                                                                        get retrieved text
# 3348                                                                                                                                                                              set background color object
# 1030                                                                                                                                returns size arguments return value methods type method used method types
# 8188                                                                                                                                                                                     adds change listener
# 555                abstract class instantiated directly type specific implementation subclasses available instantiation provide number formats storing information necessary satisfy various accessor methods
#                                                                                                          ...
# 6206    instantiates smbean instance data found mbean persistent store data loaded could include attribute operation values method called construction initialization instance mbean registered mbean nserver
# 3991                                                                                                                                                     unregisters listener longer receive ancestor revents
# 973                                                                                                                                populates crypto policy specified input tstream crypto opermissions object
# 6100                                           returns height tile given image default implementation simply returns get theight image eindex correct non tiled images readers support tiling override method
# 1210                                                                                                                                 construct new two dimensional size attribute given floating point values
# 7526                                                                                                        compares object specified object result true argument null font object name style point size font
# 2136                                                    makes copy reference using class name list addresses class factory name class factory location changes newly created copy affect reference vice versa
# 3943                                                                                   returns horizontal tile grid offset image written output stream tiling parameters set illegal lstate eexception thrown
# 7748                                                                                                                                                                                   removes binding keymap
# 8348                                                                                                                               writes class descriptor representing standard e dynamic proxy class stream
# Name: description, Length: 573, dtype: object

# %%
data['description_processed'] = descriptions_processed
data = data.drop('description3',axis=1)

# %%
data.isna().sum()

data = data.dropna()
data.head()
# Out:
#                                                               function  \
# 2496              java.nio.channels.DatagramChannel-getRemoteAddress()
# 814           javax.security.auth.callback.TextInputCallback-getText()
# 1030  jdk.internal.org.objectweb.asm.Type-getArgumentsAndReturnSizes()
# 8106                 java.util.EnumSet-complementOf(java.util.EnumSet)
# 3841                      javax.swing.text.GlyphView-getAlignment(int)
#
#                                                                                                                                                                                         description  \
# 2496                                                                                                                     Returns the remote address to which this channel's socket is connected.
# 814                                                                                                                                                                   Get the retrieved text.
# 1030                                                       Returns the size of the arguments and of the return value of methods of  this type. This method should only be used for method types.
# 8106                 Creates an enum set with the same element type as the specified enum  set, initially containing all the elements of this type that are  not contained in the specified set.
# 3841  Determines the desired alignment for this view along an  axis.  For the label, the alignment is along the font  baseline for the y axis, and the superclasses alignment  along the x axis.
#
#                                                                                                                                                                                                                                                          return_value  \
# 2496                                                                                                                                                                                        The remote address; {@code null} if the channel's socket is not connected
# 814                                                                                                                                                                                                                            the retrieved text, which may be null.
# 1030  the size of the arguments (plus one for the implicit this argument), argSize, and the size of the return value, retSize, packed into a single int i = (argSize &lt;&lt; 2) | retSize (argSize is therefore equal to i &gt;&gt; 2, and retSize to i &amp; 0x03).
# 8106                                                                                                                                                                                                                  The complement of the specified set in this set
# 3841                   the desired alignment. This should be a value between 0.0 and 1.0 inclusive, where 0 indicates alignment at the origin and 1.0 indicates alignment to the full span away from the origin. An alignment of 0.5 would be the center of the view.
#
#                                                                                                            description_processed
# 2496                                                                            returns remote address channel socket connected
# 814                                                                                                          get retrieved text
# 1030                                                  returns size arguments return value methods type method used method types
# 8106                creates enum set element type specified enum set initially containing elements type contained specified set
# 3841  determines desired alignment view along axis label alignment along font baseline axis superclasses alignment along x axis

# %%
data.to_csv('DB/Preprocessed_ontology.csv', index=False)
