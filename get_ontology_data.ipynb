# %%
from rdfpandas.graph import to_dataframe
import pandas as pd
import rdflib

# %%
g = rdflib.Graph()
g.parse('DB/Code_Ontology/comments.nt', format = 'nt')
df = to_dataframe(g)

# %%
pd.set_option('max_colwidth', 5000)
df = df.sample(frac = 0.1)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              rdfs:comment{Literal}  \
# ...

# %%
df.reset_index(level=0, inplace=True)
# Out:
#                                                                                                                                                                     index  \
# 0                                        http://rdf.webofcode.org/woc/java.awt.image.WritableRaster-WritableRaster(java.awt.image.SampleModel-java.awt.Point)-parameter-1
# 1     http://rdf.webofcode.org/woc/javax.swing.plaf.synth.SynthPainter-paintTreeBorder(javax.swing.plaf.synth.SynthContext-java.awt.Graphics-int-int-int-int)-parameter-1
# 2                      http://rdf.webofcode.org/woc/javax.swing.ProgressMonitor-ProgressMonitor(java.awt.Component-java.lang.Object-java.lang.String-int-int)-parameter-1
# 3                 http://rdf.webofcode.org/woc/javax.swing.text.StyleContext-readAttributeSet(java.io.ObjectInputStream-javax.swing.text.MutableAttributeSet)-parameter-0
# ...

# %%
data = df.sample(frac = 0.2)
data
# Out:
#                                                                                                                                                                      index  \
# 7638  http://rdf.webofcode.org/woc/jdk.internal.org.objectweb.asm.tree.analysis.Interpreter-newOperation(jdk.internal.org.objectweb.asm.tree.AbstractInsnNode)-parameter-0
# 4914                                                                                              http://rdf.webofcode.org/woc/javax.sound.sampled.EnumControl$Type-REVERB
# 3412                                                                     http://rdf.webofcode.org/woc/java.awt.image.RenderedImage-getData(java.awt.Rectangle)-parameter-0
# 5170                                                                                                 http://rdf.webofcode.org/woc/javax.accessibility.AccessibleRole-TABLE
# ...

# %%
#data.rename({'index': 'function'}, axis=1, inplace=True)
data.function

# %%
#Delete the rows where the function name contains parameter since that rows aren't defintion of functions 
data = data[~data.function.str.contains("parameter")]
data
# Out:
#                                                                                                       function  \
# 4914                                  http://rdf.webofcode.org/woc/javax.sound.sampled.EnumControl$Type-REVERB
# 5170                                     http://rdf.webofcode.org/woc/javax.accessibility.AccessibleRole-TABLE
# 8604  http://rdf.webofcode.org/woc/java.util.stream.LongStream-forEachOrdered(java.util.function.LongConsumer)
# 5410                                        http://rdf.webofcode.org/woc/java.awt.MenuItem-disableEvents(long)
# 2355       http://rdf.webofcode.org/woc/javax.accessibility.AccessibleContext-ACCESSIBLE_TABLE_SUMMARY_CHANGED
# ...                                                                                                        ...
# 3826                               http://rdf.webofcode.org/woc/java.util.WeakHashMap-DEFAULT_INITIAL_CAPACITY
# ...
