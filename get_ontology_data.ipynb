# %%
from rdfpandas.graph import to_dataframe
import pandas as pd
import rdflib
import preprocessing
import numpy as np
import tfidf
import scipy

# %%
#Load the rdf file in to a dataframe
g = rdflib.Graph()
g.parse('DB/Code_Ontology/comments.nt', format = 'nt')
df = to_dataframe(g)

# %%
pd.set_option('max_colwidth', 5000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.min_rows', 20)
df = df.sample(frac = 0.2)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
#Use the index as a column that is the name of the function 
df.reset_index(level=0, inplace=True)

# %%
#Getting a sample of db for testing
data = df.sample(frac = 0.2)
data
# Out:
#                                                                                                                                                                                        index  \
# 6001                                                                                       http://rdf.webofcode.org/woc/java.time.chrono.JapaneseEra-range(java.time.temporal.TemporalField)
# 4440   http://rdf.webofcode.org/woc/javax.swing.plaf.synth.SynthPainter-paintToolBarContentBackground(javax.swing.plaf.synth.SynthContext-java.awt.Graphics-int-int-int-int-int)-parameter-4
# 9712                                                                                                         http://rdf.webofcode.org/woc/java.time.temporal.ValueRange-getSmallestMaximum()
# 8153                                                                                                   http://rdf.webofcode.org/woc/java.net.AbstractPlainSocketImpl-listen(int)-parameter-0
# ...

# %%
#Renaming columns names 
data.rename({'index': 'function', 'rdfs:comment{Literal}' : 'description', 'rdfs:comment{Literal}(xsd:string)' : 'return_value', 'rdfs:comment{Literal}@en' : 'description3' }, axis=1, inplace=True)
#Leave only the row where the function is really a function so the line is ending with ')'
data = data.loc[(data['function'].str.endswith(')'))]

data.function
# Out:
# 6001                                                              http://rdf.webofcode.org/woc/java.time.chrono.JapaneseEra-range(java.time.temporal.TemporalField)
# 9712                                                                                http://rdf.webofcode.org/woc/java.time.temporal.ValueRange-getSmallestMaximum()
# 15484                                                                                                http://rdf.webofcode.org/woc/java.util.logging.Level-getName()
# 7539                                                                           http://rdf.webofcode.org/woc/java.util.regex.Pattern-matcher(java.lang.CharSequence)
# 16077    http://rdf.webofcode.org/woc/java.util.logging.Logger-logp(java.util.logging.Level-java.lang.String-java.lang.String-java.lang.String-java.lang.Throwable)
# 886                                                 http://rdf.webofcode.org/woc/javax.swing.plaf.TreeUI-getPathBounds(javax.swing.JTree-javax.swing.tree.TreePath)
# ...

# %%
#Delete the rows where the function name contains parameter since that rows aren't defintion of functions 
data = data[~data.function.str.contains("parameter")]
data
# Out:
#                                                                                                                                                          function  \
# 6001                                                            http://rdf.webofcode.org/woc/java.time.chrono.JapaneseEra-range(java.time.temporal.TemporalField)
# 9712                                                                              http://rdf.webofcode.org/woc/java.time.temporal.ValueRange-getSmallestMaximum()
# 15484                                                                                              http://rdf.webofcode.org/woc/java.util.logging.Level-getName()
# 7539                                                                         http://rdf.webofcode.org/woc/java.util.regex.Pattern-matcher(java.lang.CharSequence)
# 16077  http://rdf.webofcode.org/woc/java.util.logging.Logger-logp(java.util.logging.Level-java.lang.String-java.lang.String-java.lang.String-java.lang.Throwable)
# ...

# %%
preprocessing.clean_ontology(data)
data
# Out:
#                                                                                                                             function  \
# 6001                                                            java.time.chrono.JapaneseEra-range(java.time.temporal.TemporalField)
# 9712                                                                              java.time.temporal.ValueRange-getSmallestMaximum()
# 15484                                                                                              java.util.logging.Level-getName()
# 7539                                                                         java.util.regex.Pattern-matcher(java.lang.CharSequence)
# 16077  java.util.logging.Logger-logp(java.util.logging.Level-java.lang.String-java.lang.String-java.lang.String-java.lang.Throwable)
# 886                                               javax.swing.plaf.TreeUI-getPathBounds(javax.swing.JTree-javax.swing.tree.TreePath)
# ...

# %%
#count rows where due to preprocessing the description became an empty string
data[data['description'] == ''].index
# Out:
# Int64Index([ 6001,   137,  3409,  5980,  8164, 15025, 16482, 16837, 11056,
#              9651,
#             ...
#             11609, 17001,  4429,  5751, 12539, 15335, 13273, 10970, 16236,
#              2058],
#            dtype='int64', length=373)

# %%
#delete rows where due to preprocessing the description became an empty string
data = data[data['description'] != '']
data
# Out:
#                                                                                                                             function  \
# 9712                                                                              java.time.temporal.ValueRange-getSmallestMaximum()
# 15484                                                                                              java.util.logging.Level-getName()
# 7539                                                                         java.util.regex.Pattern-matcher(java.lang.CharSequence)
# 16077  java.util.logging.Logger-logp(java.util.logging.Level-java.lang.String-java.lang.String-java.lang.String-java.lang.Throwable)
# 886                                               javax.swing.plaf.TreeUI-getPathBounds(javax.swing.JTree-javax.swing.tree.TreePath)
# 9649                                                                                   javax.swing.JTable-createDefaultColumnModel()
# ...

# %%
data = data[~data['description'].isna()]
data = data[~data['function'].isna()] 
descriptions = data['description']
descriptions
# Out:
# 9712                                                                                                                                                                                                                                                                                                                                                                            Gets the smallest possible maximum value that the field can take.    For example, the ISO day-of-month runs to between 28 and 31 days.  The smallest maximum is therefore 28.
# ...

# %%
#Clearing text 
descriptions_processed = descriptions.apply(lambda x: preprocessing.clear_text(x))
descriptions_processed
# Out:
# 9712                                                                                                                                                                                                                                                                                               gets smallest possible maximum value field take example iso day month runs days smallest maximum therefore
# 15484                                                                                                                                                                                                                                                                                                                                                                  return non localized string name level
# ...

# %%
data['description_processed'] = descriptions_processed
data = data.drop('description3',axis=1)

# %%
data.isna().sum()

data = data.dropna()
data.head()
# Out:
#                                                         function  \
# 9712          java.time.temporal.ValueRange-getSmallestMaximum()
# 15484                          java.util.logging.Level-getName()
# 7539     java.util.regex.Pattern-matcher(java.lang.CharSequence)
# 9649               javax.swing.JTable-createDefaultColumnModel()
# 486    javax.swing.text.html.MuxingAttributeSet-copyAttributes()
#
#                                                                                                                                                                             description  \
# 9712   Gets the smallest possible maximum value that the field can take.    For example, the ISO day-of-month runs to between 28 and 31 days.  The smallest maximum is therefore 28.
# 15484                                                                                                                             Return the non-localized string name of the Level.
# ...

# %%
#Create matrix for tdfidf for further processing 
matrix = tfidf.create_matrix(data.description_processed)
scipy.sparse.save_npz('DB/tfidf_onto_matrix.npz', matrix)

# %%
data.to_csv('DB/Preprocessed_ontology.csv', index=False)
